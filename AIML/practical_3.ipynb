# %%
#Vedant Akare IoT-69
#Lab 3 ml
P = True
P_implies_Q = True
if P and P_implies_Q:
    Q = True
    print("Modus Ponens: Q is True")
else:
    print("Modus Ponens: Cannot conclude Q")
A = False
B = True
if not A and (A or B):
    print("Resolution: B is True")
if P or B:
    print("Expression is Satisfiable")
else:
    print("Expression is Not Satisfiable")
# Out:
# Modus Ponens: Q is True
# Resolution: B is True
# Expression is Satisfiable
